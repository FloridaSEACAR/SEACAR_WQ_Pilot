# %%
import pandas as pd
import itertools
import numpy as np

# %%
# Data Preprocessing
path = "../../"
path2 = "..\../Correlation_Analysis\WQ0416/"
#path_gis = '/Users/cong/Downloads/WaterQualityProject/SEACAR_WQ_Pilot-selected/GIS_data/'
path_gis = '..\../GIS_data/'
#WQ_file = path_gis + 'OEATUSF_Geospatial_TempSeasons.csv'
WQ_file = path2 + '..\../OEATUSF_Geospatial_TempSeasons_update_0510.csv'
#WQ_file_update = path_gis + 'OEATUSF_Geospatial_TempSeasons_update.csv'
WQ_file_update = path2+ 'OEATUSF_Geospatial_TempSeasons_update_0510_output.csv'

dfDis_orig = pd.read_csv(path + r"discrete_0214.csv")
dfCon_orig = pd.read_csv(path + r"continuous_0214.csv")
# Out:
# C:\Users\yi\AppData\Local\Temp/ipykernel_47220/1027411217.py:11: DtypeWarning: Columns (11) have mixed types. Specify dtype option on import or set low_memory=False.
#   dfDis_orig = pd.read_csv(path + r"discrete_0214.csv")

# %% [markdown]
# Add new columns to the OEATUSF_Geospatial...

# %%
count_table = pd.read_csv(WQ_file)

count_table.head()
# Out:
#    Unnamed: 0.1  Unnamed: 0 param                             ma  st_Year  \
# 0             0         147  temp    Estero Bay Aquatic Preserve     2022
# 1             1          71  temp  Biscayne Bay Aquatic Preserve     2022
# 2             2          70  temp  Biscayne Bay Aquatic Preserve     2022
# 3             3         146  temp    Estero Bay Aquatic Preserve     2022
# 4             4          69  temp  Biscayne Bay Aquatic Preserve     2022
#
#    season med_seamo_ma    s_start      s_end  date_range  \
# 0  Summer        7-Jun   6/7/2022  8/26/2022          80
# 1  Summer        1-Jun   6/1/2022  8/26/2022          86
# 2  Spring        2-Mar   3/2/2022  5/31/2022          90
# 3  Spring       27-Feb  2/27/2022   6/6/2022          99
# 4  Winter        8-Feb   2/8/2022   3/1/2022          21
#
#               covariates  Processed  \
# 0  bathymetry+LDI+popden          1
# 1  bathymetry+LDI+popden          1
# 2  bathymetry+LDI+popden          1
# 3  bathymetry+LDI+popden          1
# 4  bathymetry+LDI+popden          1
#
#                                       Total Nitrogen  \
# 0  E:/Projects/SEACAR_WQ_Pilot/GIS_data/output_ra...
# 1                                                NaN
# 2  E:/Projects/SEACAR_WQ_Pilot/GIS_data/output_ra...
# 3  E:/Projects/SEACAR_WQ_Pilot/GIS_data/output_ra...
# 4  E:/Projects/SEACAR_WQ_Pilot/GIS_data/output_ra...
#
#                                     Dissolved Oxygen  \
# 0  E:/Projects/SEACAR_WQ_Pilot/GIS_data/output_ra...
# 1                                                NaN
# 2  E:/Projects/SEACAR_WQ_Pilot/GIS_data/output_ra...
# 3  E:/Projects/SEACAR_WQ_Pilot/GIS_data/output_ra...
# 4  E:/Projects/SEACAR_WQ_Pilot/GIS_data/output_ra...
#
#                                             Salinity Secchi Depth  \
# 0                                                NaN          NaN
# 1                                                NaN          NaN
# 2  E:/Projects/SEACAR_WQ_Pilot/GIS_data/output_ra...          NaN
# 3                                                NaN          NaN
# 4  E:/Projects/SEACAR_WQ_Pilot/GIS_data/output_ra...          NaN
#
#                                            Turbidity
# 0  E:/Projects/SEACAR_WQ_Pilot/GIS_data/output_ra...
# 1                                                NaN
# 2  E:/Projects/SEACAR_WQ_Pilot/GIS_data/output_ra...
# 3  E:/Projects/SEACAR_WQ_Pilot/GIS_data/output_ra...
# 4  E:/Projects/SEACAR_WQ_Pilot/GIS_data/output_ra...

# %% [markdown]
# Combine discrete and continuous dataframe

# %%
merged_df = pd.concat([dfDis_orig, dfCon_orig])
merged_df.shape
# Out:
# (8933025, 16)

# %%
count_table['ma'] = count_table['ma'].replace('Guana River Marsh Aquatic Preserve','Guana Tolomato Matanzas National Estuarine Research Reserve')

# %% [markdown]
# Create two new columns to represent start and end date of each season

# %%
# count_table['s_start'] = count_table['med_seamo_ma'].str.replace(' ','-') +'-'+ count_table['st_Year'].astype(str)
# count_table['s_start'] = pd.to_datetime(count_table['s_start'])

# s_end_ls = []
# for area in count_table['ma'].unique():
#     table = count_table[count_table['ma']==area].reset_index()
#     table_len=table.shape[0]
#     for idx,row in table.iterrows():
#         if idx+1 < table_len:
#             row2 = table.loc[idx+1]
#             s_end = row2['s_start'] - pd.Timedelta(days=1)
#         elif idx+1 == table_len:
#             s_end = np.nan
#         s_end_ls.append(s_end)

# count_table['s_end']=s_end_ls

# %%
count_table['s_start'], count_table['s_end'] = pd.to_datetime(count_table['s_start']), pd.to_datetime(count_table['s_end'])

# %%
merged_df['date'] = pd.to_datetime(merged_df['timestamp']).dt.date

# %%
count_table['s_start'], count_table['s_end'] = count_table['s_start'].dt.date,count_table['s_end'].dt.date

# %%
ls_count = pd.DataFrame(columns=['Dissolved Oxygen','Salinity','Secchi Depth','Total Nitrogen','Turbidity'])
#ls_count = []
para_ls = merged_df['ParameterName'].unique
for idx,row in count_table.iterrows():
    #ma, s_start,s_end = row['ma'],row['st_Year'],row['s_start'], row['s_end']
    merged_df2 = merged_df.loc[(merged_df['ManagedAreaName'] == row['ma'])& 
                               (merged_df['Year'] == row['st_Year'])&
                               (merged_df['date'] > row['s_start'])&
                               (merged_df['date'] < row['s_end'])]
    merged_df3= merged_df2.groupby(['ParameterName','Latitude_DD','Longitude_DD']).size().reset_index().rename(columns={0:'Count'})
    merged_df4 = merged_df3.groupby(['ParameterName']).size().reset_index().rename(columns={0:'Count'})
    print(merged_df4)
    if merged_df3.shape[0]>0:
        ls_count = pd.concat([ls_count, merged_df4], axis=0)
    elif merged_df3.shape[0]==0:
        pd.DataFrame({'Dissolved Oxygen': np.nan,'Salinity': np.nan,'Secchi Depth': np.nan,'Total Nitrogen': np.nan,'Turbidity': np.nan})
        ls_count.append([np.nan] * 5)
# Out:
#       ParameterName  Count
# 0  Dissolved Oxygen     22
# 1          Salinity      7
# 2      Secchi Depth      3
# 3    Total Nitrogen     19
# 4         Turbidity     22
#       ParameterName  Count
# 0  Dissolved Oxygen      6
# 1          Salinity      6
# 2         Turbidity      6
#       ParameterName  Count
# 0  Dissolved Oxygen     40
# 1          Salinity     40
# 2    Total Nitrogen     33
# 3         Turbidity     39
#       ParameterName  Count
# 0  Dissolved Oxygen     23
# 1          Salinity      8
# 2      Secchi Depth      4
# 3    Total Nitrogen     22
# 4         Turbidity     25
#       ParameterName  Count
# 0  Dissolved Oxygen     20
# 1          Salinity     20
# 2    Total Nitrogen     14
# 3         Turbidity     20
#       ParameterName  Count
# 0  Dissolved Oxygen     59
# 1          Salinity     39
# 2    Total Nitrogen     54
# 3         Turbidity     38
#       ParameterName  Count
# 0  Dissolved Oxygen     44
# 1          Salinity      9
# 2      Secchi Depth      5
# 3    Total Nitrogen     43
# 4         Turbidity     47
#       ParameterName  Count
# 0  Dissolved Oxygen     21
# 1          Salinity     18
# 2      Secchi Depth     18
# 3    Total Nitrogen     17
# 4         Turbidity     17
#       ParameterName  Count
# 0  Dissolved Oxygen     39
# 1          Salinity      9
# 2      Secchi Depth      5
# 3    Total Nitrogen     36
# 4         Turbidity     40
#       ParameterName  Count
# 0  Dissolved Oxygen     43
# 1          Salinity     41
# 2      Secchi Depth     34
# 3    Total Nitrogen     51
# 4         Turbidity     44
#       ParameterName  Count
# 0  Dissolved Oxygen     60
# 1          Salinity     38
# 2      Secchi Depth      1
# 3    Total Nitrogen     54
# 4         Turbidity     38
#       ParameterName  Count
# 0  Dissolved Oxygen     50
# 1          Salinity     36
# 2    Total Nitrogen     45
# 3         Turbidity     35
#       ParameterName  Count
# 0  Dissolved Oxygen     40
# 1          Salinity     35
# 2      Secchi Depth     35
# 3    Total Nitrogen     53
# 4         Turbidity     51
#       ParameterName  Count
# 0  Dissolved Oxygen     41
# 1          Salinity     10
# 2      Secchi Depth      6
# 3    Total Nitrogen     39
# 4         Turbidity     37
#       ParameterName  Count
# 0  Dissolved Oxygen     21
# 1          Salinity     21
# 2      Secchi Depth     20
# 3    Total Nitrogen     20
# 4         Turbidity     19
#       ParameterName  Count
# 0  Dissolved Oxygen      8
# 1          Salinity      9
# 2      Secchi Depth      5
# 3    Total Nitrogen      4
# 4         Turbidity      9
#       ParameterName  Count
# 0  Dissolved Oxygen     11
# 1          Salinity      2
# 2    Total Nitrogen      8
# 3         Turbidity      3
#       ParameterName  Count
# 0  Dissolved Oxygen     51
# 1          Salinity     38
# 2    Total Nitrogen     60
# 3         Turbidity     34
#       ParameterName  Count
# 0  Dissolved Oxygen     37
# 1          Salinity      8
# 2      Secchi Depth      5
# 3    Total Nitrogen     37
# 4         Turbidity     36
#       ParameterName  Count
# 0  Dissolved Oxygen     23
# 1          Salinity     23
# 2      Secchi Depth     18
# 3    Total Nitrogen     25
# 4         Turbidity     21
#       ParameterName  Count
# 0  Dissolved Oxygen     49
# 1          Salinity     47
# 2      Secchi Depth     35
# 3    Total Nitrogen     67
# 4         Turbidity     55
#       ParameterName  Count
# 0  Dissolved Oxygen     17
# 1          Salinity     18
# 2      Secchi Depth     14
# 3    Total Nitrogen     19
# 4         Turbidity     17
#       ParameterName  Count
# 0  Dissolved Oxygen     25
# 1          Salinity     19
# 2      Secchi Depth     22
# 3    Total Nitrogen     18
# 4         Turbidity     24
#       ParameterName  Count
# 0  Dissolved Oxygen     34
# 1          Salinity      3
# 2    Total Nitrogen     38
# 3         Turbidity     36
#       ParameterName  Count
# 0  Dissolved Oxygen     11
# 1          Salinity      9
# 2      Secchi Depth      3
# 3    Total Nitrogen     20
# 4         Turbidity     14
#       ParameterName  Count
# 0  Dissolved Oxygen     55
# 1          Salinity     42
# 2      Secchi Depth     15
# 3    Total Nitrogen     62
# 4         Turbidity     42
#       ParameterName  Count
# 0  Dissolved Oxygen     46
# 1          Salinity     30
# 2      Secchi Depth     16
# 3    Total Nitrogen     46
# 4         Turbidity     30
#       ParameterName  Count
# 0  Dissolved Oxygen     37
# 1          Salinity     37
# 2      Secchi Depth     35
# 3    Total Nitrogen     53
# 4         Turbidity     51
#       ParameterName  Count
# 0  Dissolved Oxygen     36
# 1          Salinity      7
# 2      Secchi Depth      4
# 3    Total Nitrogen     36
# 4         Turbidity     39
#       ParameterName  Count
# 0  Dissolved Oxygen     21
# 1          Salinity     21
# 2      Secchi Depth     17
# 3    Total Nitrogen     21
# 4         Turbidity     19
#       ParameterName  Count
# 0  Dissolved Oxygen     46
# 1          Salinity     38
# 2      Secchi Depth     33
# 3    Total Nitrogen     43
# 4         Turbidity     43
#       ParameterName  Count
# 0  Dissolved Oxygen     10
# 1          Salinity     10
# 2      Secchi Depth      6
# 3    Total Nitrogen      5
# 4         Turbidity      9
#       ParameterName  Count
# 0  Dissolved Oxygen      2
# 1          Salinity      3
# 2         Turbidity      3
#       ParameterName  Count
# 0  Dissolved Oxygen     13
# 1          Salinity     12
# 2      Secchi Depth     17
# 3    Total Nitrogen     10
# 4         Turbidity     13
#       ParameterName  Count
# 0  Dissolved Oxygen     41
# 1          Salinity     45
# 2      Secchi Depth     17
# 3    Total Nitrogen     45
# 4         Turbidity     42
#       ParameterName  Count
# 0  Dissolved Oxygen     16
# 1          Salinity     16
# 2      Secchi Depth     16
# 3    Total Nitrogen     16
# 4         Turbidity     16
#       ParameterName  Count
# 0  Dissolved Oxygen     38
# 1          Salinity      3
# 2    Total Nitrogen     36
# 3         Turbidity     34
#       ParameterName  Count
# 0  Dissolved Oxygen      7
# 1          Salinity      4
# 2      Secchi Depth      1
# 3    Total Nitrogen     14
# 4         Turbidity      7
#       ParameterName  Count
# 0  Dissolved Oxygen      2
# 1    Total Nitrogen     21
# 2         Turbidity     21
#       ParameterName  Count
# 0  Dissolved Oxygen      7
# 1          Salinity      7
# 2      Secchi Depth      1
# 3    Total Nitrogen     12
# 4         Turbidity      7
#       ParameterName  Count
# 0  Dissolved Oxygen     38
# 1          Salinity     38
# 2      Secchi Depth      7
# 3    Total Nitrogen     40
# 4         Turbidity     27
#       ParameterName  Count
# 0  Dissolved Oxygen     32
# 1          Salinity      3
# 2    Total Nitrogen     30
# 3         Turbidity     35
#       ParameterName  Count
# 0  Dissolved Oxygen      2
# 1    Total Nitrogen     13
# 2         Turbidity     12
#       ParameterName  Count
# 0  Dissolved Oxygen     17
# 1          Salinity     17
# 2      Secchi Depth     16
# 3    Total Nitrogen     16
# 4         Turbidity     16
#       ParameterName  Count
# 0  Dissolved Oxygen     16
# 1          Salinity     16
# 2      Secchi Depth     16
# 3    Total Nitrogen     16
# 4         Turbidity     16
#       ParameterName  Count
# 0  Dissolved Oxygen      2
# 1    Total Nitrogen     19
# 2         Turbidity     19
#       ParameterName  Count
# 0  Dissolved Oxygen     28
# 1          Salinity      3
# 2    Total Nitrogen     28
# 3         Turbidity     31
#       ParameterName  Count
# 0  Dissolved Oxygen      7
# 1          Salinity      7
# 2      Secchi Depth      1
# 3    Total Nitrogen     13
# 4         Turbidity      3
#       ParameterName  Count
# 0  Dissolved Oxygen     28
# 1          Salinity     28
# 2      Secchi Depth      5
# 3    Total Nitrogen     49
# 4         Turbidity      4
#       ParameterName  Count
# 0  Dissolved Oxygen      3
# 1          Salinity      3
# 2         Turbidity      3
#       ParameterName  Count
# 0  Dissolved Oxygen      1
# 1          Salinity      1
# 2         Turbidity      1
#       ParameterName  Count
# 0  Dissolved Oxygen     15
# 1          Salinity     15
# 2      Secchi Depth      9
# 3    Total Nitrogen     20
# 4         Turbidity      6
#       ParameterName  Count
# 0  Dissolved Oxygen     43
# 1          Salinity      9
# 2    Total Nitrogen     37
# 3         Turbidity     40
#       ParameterName  Count
# 0  Dissolved Oxygen     17
# 1          Salinity     17
# 2      Secchi Depth      6
# 3    Total Nitrogen     20
# 4         Turbidity     13
#       ParameterName  Count
# 0  Dissolved Oxygen     12
# 1          Salinity     10
# 2    Total Nitrogen     17
# 3         Turbidity     17
#       ParameterName  Count
# 0  Dissolved Oxygen     17
# 1          Salinity     15
# 2      Secchi Depth      1
# 3    Total Nitrogen     15
# 4         Turbidity      5
#       ParameterName  Count
# 0  Dissolved Oxygen     38
# 1          Salinity     10
# 2      Secchi Depth      3
# 3    Total Nitrogen     31
# 4         Turbidity     34
#       ParameterName  Count
# 0  Dissolved Oxygen      6
# 1          Salinity      4
# 2    Total Nitrogen     17
# 3         Turbidity     17
#       ParameterName  Count
# 0  Dissolved Oxygen      6
# 1          Salinity      4
# 2    Total Nitrogen     16
# 3         Turbidity     16
#       ParameterName  Count
# 0  Dissolved Oxygen     35
# 1          Salinity     11
# 2    Total Nitrogen     27
# 3         Turbidity     31
#       ParameterName  Count
# 0  Dissolved Oxygen     15
# 1          Salinity     15
# 2      Secchi Depth      4
# 3    Total Nitrogen     10
# 4         Turbidity      4
#       ParameterName  Count
# 0  Dissolved Oxygen     14
# 1          Salinity     14
# 2      Secchi Depth      4
# 3    Total Nitrogen     10
# 4         Turbidity      3
#       ParameterName  Count
# 0  Dissolved Oxygen     46
# 1          Salinity     11
# 2    Total Nitrogen     35
# 3         Turbidity     39
#       ParameterName  Count
# 0  Dissolved Oxygen     57
# 1          Salinity     57
# 2      Secchi Depth      6
# 3    Total Nitrogen     10
# 4         Turbidity      2
#       ParameterName  Count
# 0  Dissolved Oxygen    298
# 1          Salinity    274
# 2      Secchi Depth    244
# 3    Total Nitrogen     24
# 4         Turbidity     24
#       ParameterName  Count
# 0  Dissolved Oxygen     13
# 1          Salinity     15
# 2      Secchi Depth      5
# 3    Total Nitrogen      8
# 4         Turbidity      2
#       ParameterName  Count
# 0  Dissolved Oxygen     40
# 1          Salinity     10
# 2      Secchi Depth      3
# 3    Total Nitrogen     33
# 4         Turbidity     33
#       ParameterName  Count
# 0  Dissolved Oxygen    176
# 1          Salinity    168
# 2      Secchi Depth    139
# 3    Total Nitrogen      8
# 4         Turbidity      8
#       ParameterName  Count
# 0  Dissolved Oxygen    200
# 1          Salinity    185
# 2      Secchi Depth    168
# 3    Total Nitrogen     16
# 4         Turbidity     16
#       ParameterName  Count
# 0  Dissolved Oxygen     41
# 1          Salinity     10
# 2    Total Nitrogen     31
# 3         Turbidity     35
#       ParameterName  Count
# 0  Dissolved Oxygen     50
# 1          Salinity     47
# 2      Secchi Depth      1
# 3    Total Nitrogen      8
# 4         Turbidity      7
#       ParameterName  Count
# 0  Dissolved Oxygen      3
# 1          Salinity      3
# 2         Turbidity      3
#       ParameterName  Count
# 0  Dissolved Oxygen     46
# 1          Salinity     10
# 2    Total Nitrogen     37
# 3         Turbidity     40
#       ParameterName  Count
# 0  Dissolved Oxygen     28
# 1          Salinity     25
# 2    Total Nitrogen      4
# 3         Turbidity      7
#       ParameterName  Count
# 0  Dissolved Oxygen    294
# 1          Salinity    314
# 2      Secchi Depth    269
# 3    Total Nitrogen     22
# 4         Turbidity     17
#       ParameterName  Count
# 0  Dissolved Oxygen     56
# 1          Salinity     53
# 2    Total Nitrogen      4
# 3         Turbidity      7
#       ParameterName  Count
# 0  Dissolved Oxygen     41
# 1          Salinity     10
# 2    Total Nitrogen     31
# 3         Turbidity     34
#       ParameterName  Count
# 0  Dissolved Oxygen    191
# 1          Salinity    180
# 2      Secchi Depth    154
# 3    Total Nitrogen     20
# 4         Turbidity     12
#       ParameterName  Count
# 0  Dissolved Oxygen    221
# 1          Salinity    214
# 2      Secchi Depth    198
# 3    Total Nitrogen     20
# 4         Turbidity     18
#       ParameterName  Count
# 0  Dissolved Oxygen     45
# 1          Salinity     12
# 2      Secchi Depth      2
# 3    Total Nitrogen     39
# 4         Turbidity     37
#       ParameterName  Count
# 0  Dissolved Oxygen     57
# 1          Salinity     54
# 2    Total Nitrogen      5
# 3         Turbidity      9
#       ParameterName  Count
# 0  Dissolved Oxygen     14
# 1          Salinity     11
# 2    Total Nitrogen      4
# 3         Turbidity      8
#       ParameterName  Count
# 0  Dissolved Oxygen    520
# 1          Salinity    516
# 2      Secchi Depth    341
# 3    Total Nitrogen     33
# 4         Turbidity     19
#       ParameterName  Count
# 0  Dissolved Oxygen     50
# 1          Salinity     10
# 2      Secchi Depth      4
# 3    Total Nitrogen     46
# 4         Turbidity     44
#       ParameterName  Count
# 0  Dissolved Oxygen     58
# 1          Salinity     59
# 2      Secchi Depth      3
# 3    Total Nitrogen      8
# 4         Turbidity     11
#       ParameterName  Count
# 0  Dissolved Oxygen    288
# 1          Salinity    296
# 2      Secchi Depth    266
# 3    Total Nitrogen     57
# 4         Turbidity     49
#       ParameterName  Count
# 0  Dissolved Oxygen     58
# 1          Salinity     59
# 2      Secchi Depth      5
# 3    Total Nitrogen      7
# 4         Turbidity      9
#       ParameterName  Count
# 0  Dissolved Oxygen    378
# 1          Salinity    367
# 2      Secchi Depth    202
# 3    Total Nitrogen     20
# 4         Turbidity     19
#       ParameterName  Count
# 0  Dissolved Oxygen     38
# 1          Salinity      8
# 2      Secchi Depth      4
# 3    Total Nitrogen     36
# 4         Turbidity     33
#       ParameterName  Count
# 0  Dissolved Oxygen    196
# 1          Salinity    197
# 2      Secchi Depth    187
# 3    Total Nitrogen     20
# 4         Turbidity     17
#       ParameterName  Count
# 0  Dissolved Oxygen    333
# 1          Salinity    333
# 2      Secchi Depth    316
# 3    Total Nitrogen     49
# 4         Turbidity     46
#       ParameterName  Count
# 0  Dissolved Oxygen     47
# 1          Salinity     10
# 2      Secchi Depth      4
# 3    Total Nitrogen     45
# 4         Turbidity     41
#       ParameterName  Count
# 0  Dissolved Oxygen     63
# 1          Salinity     64
# 2      Secchi Depth      4
# 3    Total Nitrogen      7
# 4         Turbidity     11
#       ParameterName  Count
# 0  Dissolved Oxygen    490
# 1          Salinity    484
# 2      Secchi Depth    319
# 3    Total Nitrogen     40
# 4         Turbidity     21
#       ParameterName  Count
# 0  Dissolved Oxygen     14
# 1          Salinity     14
# 2    Total Nitrogen      4
# 3         Turbidity      8
#       ParameterName  Count
# 0  Dissolved Oxygen    143
# 1          Salinity    165
# 2      Secchi Depth     85
# 3    Total Nitrogen     16
# 4         Turbidity     13
#       ParameterName  Count
# 0  Dissolved Oxygen    576
# 1          Salinity    566
# 2      Secchi Depth    350
# 3    Total Nitrogen     46
# 4         Turbidity     28
#       ParameterName  Count
# 0  Dissolved Oxygen     44
# 1          Salinity     10
# 2      Secchi Depth      3
# 3    Total Nitrogen     40
# 4         Turbidity     38
#       ParameterName  Count
# 0  Dissolved Oxygen     56
# 1          Salinity     59
# 2      Secchi Depth     15
# 3    Total Nitrogen      8
# 4         Turbidity      8
#       ParameterName  Count
# 0  Dissolved Oxygen    473
# 1          Salinity    461
# 2      Secchi Depth    421
# 3    Total Nitrogen     72
# 4         Turbidity     63
#       ParameterName  Count
# 0  Dissolved Oxygen     74
# 1          Salinity     73
# 2      Secchi Depth     17
# 3    Total Nitrogen      8
# 4         Turbidity      8
#       ParameterName  Count
# 0  Dissolved Oxygen    395
# 1          Salinity    388
# 2      Secchi Depth    217
# 3    Total Nitrogen     33
# 4         Turbidity     18
#       ParameterName  Count
# 0  Dissolved Oxygen     36
# 1          Salinity      9
# 2      Secchi Depth      3
# 3    Total Nitrogen     33
# 4         Turbidity     31
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_47220/1396571985.py in <cell line: 4>()
#       5     #ma, s_start,s_end = row['ma'],row['st_Year'],row['s_start'], row['s_end']
#       6     merged_df2 = merged_df.loc[(merged_df['ManagedAreaName'] == row['ma'])&
# ----> 7                                (merged_df['Year'] == row['st_Year'])&
#       8                                (merged_df['date'] > row['s_start'])&
#       9                                (merged_df['date'] < row['s_end'])]
#
# ~\.conda\envs\geo\lib\site-packages\pandas\core\ops\common.py in new_method(self, other)
#      68         other = item_from_zerodim(other)
#      69
# ---> 70         return method(self, other)
#      71
#      72     return new_method
#
# ~\.conda\envs\geo\lib\site-packages\pandas\core\arraylike.py in __eq__(self, other)
#      38     @unpack_zerodim_and_defer("__eq__")
#      39     def __eq__(self, other):
# ---> 40         return self._cmp_method(other, operator.eq)
#      41
#      42     @unpack_zerodim_and_defer("__ne__")
#
# ~\.conda\envs\geo\lib\site-packages\pandas\core\series.py in _cmp_method(self, other, op)
#    5621
#    5622         with np.errstate(all="ignore"):
# -> 5623             res_values = ops.comparison_op(lvalues, rvalues, op)
#    5624
#    5625         return self._construct_result(res_values, name=res_name)
#
# ~\.conda\envs\geo\lib\site-packages\pandas\core\ops\array_ops.py in comparison_op(left, right, op)
#     284
#     285     else:
# --> 286         res_values = _na_arithmetic_op(lvalues, rvalues, op, is_cmp=True)
#     287
#     288     return res_values
#
# ~\.conda\envs\geo\lib\site-packages\pandas\core\ops\array_ops.py in _na_arithmetic_op(left, right, op, is_cmp)
#     161
#     162     try:
# --> 163         result = func(left, right)
#     164     except TypeError:
#     165         if not is_cmp and (is_object_dtype(left.dtype) or is_object_dtype(right)):
#
# ~\.conda\envs\geo\lib\site-packages\pandas\core\computation\expressions.py in evaluate(op, a, b, use_numexpr)
#     237         if use_numexpr:
#     238             # error: "None" not callable
# --> 239             return _evaluate(op, op_str, a, b)  # type: ignore[misc]
#     240     return _evaluate_standard(op, op_str, a, b)
#     241
#
# ~\.conda\envs\geo\lib\site-packages\pandas\core\computation\expressions.py in _evaluate_standard(op, op_str, a, b)
#      67     if _TEST_MODE:
#      68         _store_test_result(False)
# ---> 69     return op(a, b)
#      70
#      71
#
# KeyboardInterrupt:

# %%
ls_count
# Out:
# [[22, 7, 3, 19, 22],
#  [6, 6, 6],
#  [40, 40, 33, 39],
#  [23, 8, 4, 22, 25],
#  [20, 20, 14, 20],
#  [59, 39, 54, 38],
#  [44, 9, 5, 43, 47],
#  [21, 18, 18, 17, 17],
#  [39, 9, 5, 36, 40],
#  [43, 41, 34, 51, 44],
#  [60, 38, 1, 54, 38],
#  [50, 36, 45, 35],
#  [40, 35, 35, 53, 51],
#  [41, 10, 6, 39, 37],
#  [21, 21, 20, 20, 19],
#  [8, 9, 5, 4, 9],
#  [11, 2, 8, 3],
#  [51, 38, 60, 34],
#  [37, 8, 5, 37, 36]]

# %%
df_count = pd.DataFrame(ls_count, columns = ['Dissolved Oxygen','Salinity','Secchi Depth','Total Nitrogen','Turbidity'])

# %%
count_table = pd.concat([count_table, df_count], axis=1)

# %%
count_table.to_csv(WQ_file_update, index=False)
